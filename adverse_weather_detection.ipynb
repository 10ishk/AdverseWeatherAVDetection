# %% [markdown]
# # Adverse Weather Object Detection with YOLOv5
#
# This notebook implements an object detection system for autonomous vehicles under adverse weather conditions (rainy, foggy, snowy) using YOLOv5s and the BDD100K dataset. It includes:
#
# 1. Filtering a subset of ~1,000 images from BDD100K with adverse weather.
# 2. Training YOLOv5s on this subset.
# 3. Evaluating the model and saving results.
# 4. Running inference and saving output images.
# 5. Saving all results for later presentation without retraining.
#
# **Hardware**: RTX 3050 4GB VRAM, Ryzen 7 4800H, 16GB RAM, 90GB free storage.

# %%
# Install dependencies and clone YOLOv5 (run only if not already installed)
# !pip install torch==2.3.0+cu118 torchvision==0.18.0+cu118 --index-url https://download.pytorch.org/whl/cu118
# !pip install opencv-python albumentations pyyaml tqdm
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch==2.3.0+cu118 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (2.3.0+cu118)
# Requirement already satisfied: torchvision==0.18.0+cu118 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (0.18.0+cu118)
# Requirement already satisfied: filelock in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torch==2.3.0+cu118) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torch==2.3.0+cu118) (4.12.2)
# Requirement already satisfied: sympy in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torch==2.3.0+cu118) (1.13.1)
# Requirement already satisfied: networkx in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torch==2.3.0+cu118) (3.3)
# Requirement already satisfied: jinja2 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torch==2.3.0+cu118) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torch==2.3.0+cu118) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torch==2.3.0+cu118) (2021.4.0)
# Requirement already satisfied: numpy in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torchvision==0.18.0+cu118) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from torchvision==0.18.0+cu118) (10.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.0+cu118) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.0+cu118) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from jinja2->torch==2.3.0+cu118) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from sympy->torch==2.3.0+cu118) (1.3.0)
# Requirement already satisfied: opencv-python in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (4.10.0.84)
# Requirement already satisfied: albumentations in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (2.0.6)
# Requirement already satisfied: pyyaml in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (6.0.1)
# Requirement already satisfied: tqdm in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (4.66.4)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from albumentations) (1.14.0)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from albumentations) (2.10.5)
# Requirement already satisfied: albucore==0.0.24 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from albucore==0.0.24->albumentations) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from albucore==0.0.24->albumentations) (6.2.1)
# Requirement already satisfied: colorama in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\atbru\downloads\code\ai_ml_dl\.ml\lib\site-packages (from pydantic>=2.9.2->albumentations) (4.12.2)

# %% [markdown]
# ## Step 1: Filter BDD100K Dataset for Adverse Weather
#
# Filter ~1,000 images from the BDD100K dataset (train split) with adverse weather conditions (rainy, foggy, snowy). Save them to `dataset/images/train` with dummy labels in `dataset/labels/train`.

# %%
import json
import os
import shutil
from pathlib import Path
import random
import cv2

# Paths
BDD100K_ROOT = "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/bdd100k"
OUTPUT_DIR = "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/dataset"
MAX_IMAGES_TRAIN = 1000  # Number of training images
MAX_IMAGES_VAL = 200     # Number of validation images
WEATHER_CLASSES = ["rainy", "foggy", "snowy"]
YOLO_CLASSES = {"car": 0}  # Add more classes if needed

def convert_bbox_to_yolo(bbox, img_width, img_height):
    x1, y1, x2, y2 = bbox
    x_center = ((x1 + x2) / 2.0) / img_width
    y_center = ((y1 + y2) / 2.0) / img_height
    width = (x2 - x1) / img_width
    height = (y2 - y1) / img_height
    return x_center, y_center, width, height

def filter_adverse_weather(root_dir, output_dir, max_images_train, max_images_val):
    # Process both train and val splits
    for split in ["train", "val"]:
        images_dir = os.path.join(root_dir, f"{split}/images")
        labels_file = os.path.join(root_dir, f"{split}/annotations/bdd100k_labels_images_{split}.json")
        output_images = os.path.join(output_dir, f"images/{split}")
        output_labels = os.path.join(output_dir, f"labels/{split}")

        # Create output directories
        os.makedirs(output_images, exist_ok=True)
        os.makedirs(output_labels, exist_ok=True)

        # Check if label file exists
        if not os.path.exists(labels_file):
            print(f"Label file not found for {split} split: {labels_file}")
            continue

        # Load annotations
        with open(labels_file, 'r') as f:
            data = json.load(f)

        # Filter for adverse weather
        adverse_data = [entry for entry in data if entry.get("attributes", {}).get("weather", "clear") in WEATHER_CLASSES]

        # Set max images based on split
        max_images = max_images_train if split == "train" else max_images_val
        if len(adverse_data) == 0:
            print(f"No adverse weather images found in {split} split.")
            continue

        selected = random.sample(adverse_data, min(max_images, len(adverse_data)))

        for entry in selected:
            image_name = entry["name"]
            src_img_path = os.path.join(images_dir, image_name)
            dst_img_path = os.path.join(output_images, image_name)

            if not os.path.exists(src_img_path):
                print(f"Image not found: {src_img_path}")
                continue

            # Load image to get dimensions
            img = cv2.imread(src_img_path)
            if img is None:
                print(f"Warning: Could not load image {src_img_path}, skipping...")
                continue
            img_height, img_width = img.shape[:2]

            # Copy the image
            shutil.copy(src_img_path, dst_img_path)

            # Generate label file
            label_path = os.path.join(output_labels, image_name.replace(".jpg", ".txt"))
            with open(label_path, 'w') as f:
                for label in entry.get("labels", []):
                    category = label.get("category")
                    if category not in YOLO_CLASSES:
                        continue

                    bbox = label.get("box2d")
                    if not bbox:
                        continue

                    x1 = bbox.get("x1")
                    y1 = bbox.get("y1")
                    x2 = bbox.get("x2")
                    y2 = bbox.get("y2")
                    if None in [x1, y1, x2, y2]:
                        continue

                    # Convert to YOLO format using actual image dimensions
                    yolo_box = convert_bbox_to_yolo([x1, y1, x2, y2], img_width, img_height)
                    class_id = YOLO_CLASSES[category]
                    f.write(f"{class_id} {' '.join(f'{x:.6f}' for x in yolo_box)}\n")

        print(f"✔ Processed {split} split: {len(selected)} images with YOLO annotations.")

# Run the filtering
filter_adverse_weather(BDD100K_ROOT, OUTPUT_DIR, MAX_IMAGES_TRAIN, MAX_IMAGES_VAL)
# Out:
# ✔ Processed train split: 1000 images with YOLO annotations.
# ✔ Processed val split: 200 images with YOLO annotations.

# %% [markdown]
# ## Step 2: Configure YOLOv5
#
# Create a `data.yaml` file to specify the dataset paths and classes for YOLOv5 training.

# %%
# Create data.yaml file with augmentations
data_yaml_content = """
train: C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/dataset/images/train
val: C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/dataset/images/val
nc: 1
names: ['car']
# Augmentation parameters
hsv_h: 0.015  # Hue augmentation (fraction)
hsv_s: 0.7    # Saturation augmentation (fraction, increased to simulate weather effects)
hsv_v: 0.4    # Value (brightness) augmentation (fraction, increased for contrast)
degrees: 0.0  # Image rotation (+/- degrees)
translate: 0.1  # Image translation (+/- fraction)
scale: 0.5    # Image scale (+/- gain)
shear: 0.0    # Image shear (+/- degrees)
perspective: 0.0  # Image perspective (+/- fraction)
flipud: 0.0   # Image flip up-down (probability)
fliplr: 0.5   # Image flip left-right (probability)
mosaic: 1.0   # Mosaic augmentation (probability)
mixup: 0.0    # Mixup augmentation (probability)
"""

with open("data.yaml", "w") as f:
    f.write(data_yaml_content)

print("data.yaml created successfully.")
# Out:
# data.yaml created successfully.

# %%
import os

# Check if yolov5 directory exists, if not clone it, otherwise pull the latest changes
if not os.path.exists("yolov5"):
    # !git clone https://github.com/ultralytics/yolov5
    os.chdir("yolov5")
    # !git checkout master
    # !git pull
    os.chdir("..")
else:
    os.chdir("yolov5")
    # !git checkout master
    # !git pull
    os.chdir("..")

print("YOLOv5 updated to the latest version.")
# Out:
# Your branch is up to date with 'origin/master'.
# Already on 'master'
# Already up to date.
# YOLOv5 updated to the latest version.

# %% [markdown]
# ## Step 3: Train YOLOv5s
#
# Train YOLOv5s on the filtered dataset for 10 epochs. Save the trained weights for later use.

# %%
import torch
import subprocess
import os

# Set the working directory to the project root
os.chdir("C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles")

# Define the training command as a list of arguments with absolute paths
train_command = [
    "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/.ML/Scripts/python.exe",
    "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/yolov5/train.py",
    "--data", "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/data.yaml",
    "--imgsz", "416",
    "--batch-size", "2",  # Reduced to avoid VRAM issues
    "--epochs", "10",
    "--weights", "yolov5s.pt",
    "--device", "0",  # Force GPU device 0
    "--project", "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs",
    "--name", "adverse_weather_exp",
    "--workers", "4"
]

# Propagate the current environment and add CUDA-related variables
env = os.environ.copy()
env["CUDA_VISIBLE_DEVICES"] = "0"  # Explicitly set visible GPU to device 0
result = subprocess.run(train_command, capture_output=True, text=True, env=env)
print("Training Output:")
print(result.stdout)
if result.stderr:
    print("Training Errors:")
    print(result.stderr)

# Check if training was successful
if result.returncode == 0:
    print("Training complete. Model weights saved to runs/adverse_weather_exp/weights/best.pt")
else:
    print("Training failed. See errors above.")
# Out:
# Exception in thread Thread-14 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\ATbru\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "c:\Users\ATbru\Downloads\CODE\AI_ML_DL\.ML\Lib\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\ATbru\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ATbru\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1599, in _readerthread
#     buffer.append(fh.read())
#                   ^^^^^^^^^
#   File "C:\Users\ATbru\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 5856: character maps to <undefined>
# Training Output:
#
# Training complete. Model weights saved to runs/adverse_weather_exp/weights/best.pt

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")
# Out:
# Torch version: 2.3.0+cu118
# CUDA available: True
# CUDA version: 11.8
# GPU name: NVIDIA GeForce RTX 3050 Laptop GPU

# %% [markdown]
# ## Step 4: Evaluate the Model
#
# Evaluate the trained model to get mAP and save the results for later use.

# %%
import subprocess
import json
import os
import glob

# Define the validation command as a list of arguments
val_command = [
    "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/.ML/Scripts/python.exe",  # Corrected path to Python executable
    "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/yolov5/val.py",  # Absolute path to val.py
    "--weights", "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs/adverse_weather_exp/weights/best.pt",
    "--data", "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/data.yaml",
    "--imgsz", "416",
    "--device", "0" if torch.cuda.is_available() else "cpu",
    "--task", "val"
]

# Run the command and capture output
result = subprocess.run(val_command, capture_output=True, text=True)
print("Validation Output:")
print(result.stdout)
if result.stderr:
    print("Validation Errors:")
    print(result.stderr)

# Parse the last run's results (YOLOv5 saves them in runs/val/exp*/results.json)
val_exp_dir = max([d for d in glob.glob("C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs/val/exp*")], key=os.path.getmtime, default=None)
if val_exp_dir:
    results_path = os.path.join(val_exp_dir, "results.json")
    if os.path.exists(results_path):
        with open(results_path, "r") as f:
            metrics = json.load(f)
        # Save metrics to your custom file
        with open("C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/evaluation_metrics.json", "w") as f:
            json.dump(metrics, f)
        print("Evaluation complete. Metrics saved to evaluation_metrics.json")
        # YOLOv5 results.json typically contains mAP metrics
        print("mAP@0.5:", metrics.get("metrics/mAP50", "Not found"))
    else:
        print("Evaluation completed, but results.json not found in", val_exp_dir)
else:
    print("Evaluation failed. No validation run found. See errors above.")
# Out:
# Validation Output:
#
# Validation Errors:
# val: data=C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/data.yaml, weights=['C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs/adverse_weather_exp/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5\runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-416-gfe1d4d99 Python-3.12.4 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Traceback (most recent call last):
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\yolov5\val.py", line 604, in <module>
#     main(opt)
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\yolov5\val.py", line 575, in main
#     run(**vars(opt))
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\.ML\Lib\site-packages\torch\utils\_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\yolov5\val.py", line 270, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\yolov5\models\common.py", line 489, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\yolov5\models\experimental.py", line 98, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location="cpu")  # load
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\.ML\Lib\site-packages\ultralytics\utils\patches.py", line 115, in torch_load
#     return _torch_load(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\.ML\Lib\site-packages\torch\serialization.py", line 997, in load
#     with _open_file_like(f, 'rb') as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\.ML\Lib\site-packages\torch\serialization.py", line 444, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ATbru\Downloads\CODE\AI_ML_DL\.ML\Lib\site-packages\torch\serialization.py", line 425, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ATbru\\Downloads\\CODE\\AI_ML_DL\\Autonomus_Vehicles\\runs\\adverse_weather_exp\\weights\\best.pt'
#
# Evaluation failed. No validation run found. See errors above.

# %% [markdown]
# ## Step 5: Run Inference and Save Results
#
# Run inference on the training set and save the output images for presentation.

# %%
from yolov5 import detect

# Run inference
detect.run(
    weights='C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs/adverse_weather_exp5/weights/best.pt',
    source='C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/dataset/images/train',
    imgsz=(416, 416),  # Changed to tuple
    conf_thres=0.4,
    device=0 if torch.cuda.is_available() else 'cpu',
    project='C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs',
    name='infer',
    save_txt=True,
    save_conf=True
)

print("Inference complete. Results saved to runs/infer")
# Out:
# YOLOv5  v7.0-416-gfe1d4d99 Python-3.12.4 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00091078-84635cf2.jpg: 256x416 5 cars, 393.0ms
# image 2/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00091078-c1d32eea.jpg: 256x416 7 cars, 31.0ms
# image 3/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00091078-f32de4d2.jpg: 256x416 4 cars, 31.0ms
# image 4/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0010bf16-9ee17cd9.jpg: 256x416 3 cars, 32.0ms
# image 5/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0024b742-acbed4fb.jpg: 256x416 5 cars, 31.0ms
# image 6/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\002f8552-0cdd55c6.jpg: 256x416 8 cars, 30.0ms
# image 7/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0051e391-d32a618e.jpg: 256x416 6 cars, 28.0ms
# image 8/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0062e803-38c0a33a.jpg: 256x416 14 cars, 29.0ms
# image 9/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00690c26-e4bbbd72.jpg: 256x416 7 cars, 28.0ms
# image 10/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00699de6-58847872.jpg: 256x416 5 cars, 27.0ms
# image 11/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\006bff20-752bd845.jpg: 256x416 13 cars, 27.0ms
# image 12/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0070bc56-8d8cfd82.jpg: 256x416 10 cars, 27.0ms
# image 13/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0075a5b0-9a8d5dbb.jpg: 256x416 3 cars, 14.0ms
# image 14/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\007c01ea-63aa326c.jpg: 256x416 7 cars, 14.0ms
# image 15/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\007c01ea-a02f29ef.jpg: 256x416 3 cars, 15.0ms
# image 16/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\007c01ea-ad9f940b.jpg: 256x416 5 cars, 14.0ms
# image 17/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\007eddfc-528c4da4.jpg: 256x416 3 cars, 14.0ms
# image 18/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\007eddfc-f8a80310.jpg: 256x416 2 cars, 18.0ms
# image 19/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00810e80-37641274.jpg: 256x416 2 cars, 14.0ms
# image 20/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0081da60-27997c07.jpg: 256x416 8 cars, 21.0ms
# image 21/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0088cf04-319858ad.jpg: 256x416 3 cars, 14.0ms
# image 22/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00982f76-83a093ef.jpg: 256x416 2 cars, 18.0ms
# image 23/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\009b0eb2-bbef939f.jpg: 256x416 8 cars, 14.0ms
# image 24/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00b04b30-2e874876.jpg: 256x416 3 cars, 24.0ms
# image 25/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00b56f41-e0e5d918.jpg: 256x416 2 cars, 15.0ms
# image 26/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00c12bd0-bb46e479.jpg: 256x416 8 cars, 14.0ms
# image 27/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00c17a92-d4803287.jpg: 256x416 8 cars, 14.0ms
# image 28/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00cea101-293a30b5.jpg: 256x416 (no detections), 14.0ms
# image 29/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00d1bafa-1b47b41c.jpg: 256x416 3 cars, 15.0ms
# image 30/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00d5edb9-f0077df3.jpg: 256x416 2 cars, 14.0ms
# image 31/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00e02d60-54df99d1.jpg: 256x416 7 cars, 14.0ms
# image 32/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\00f42f6b-5a20a4d2.jpg: 256x416 8 cars, 14.0ms
# image 33/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0104eb19-162abfea.jpg: 256x416 9 cars, 14.0ms
# image 34/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\010b0600-f44aed15.jpg: 256x416 5 cars, 14.0ms
# image 35/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01440a35-e0b2f4a2.jpg: 256x416 13 cars, 17.0ms
# image 36/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01460ec4-522da2d6.jpg: 256x416 9 cars, 19.0ms
# image 37/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\015f02db-80d95c9f.jpg: 256x416 8 cars, 14.0ms
# image 38/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\018d962a-fd869a57.jpg: 256x416 4 cars, 17.0ms
# image 39/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0193a01e-90028c79.jpg: 256x416 2 cars, 14.0ms
# image 40/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\019c8305-3a3be0d6.jpg: 256x416 2 cars, 14.0ms
# image 41/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\019d6206-d5de804a.jpg: 256x416 7 cars, 14.0ms
# image 42/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01a01af7-76f6a476.jpg: 256x416 5 cars, 14.0ms
# image 43/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01ad8d8a-49bb0c93.jpg: 256x416 5 cars, 14.0ms
# image 44/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01bb1cc0-cea208cc.jpg: 256x416 4 cars, 14.0ms
# image 45/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01c2e726-414a03ea.jpg: 256x416 4 cars, 14.0ms
# image 46/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01c6a5ce-7dba0d93.jpg: 256x416 3 cars, 14.0ms
# image 47/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01d250e0-8352d1f1.jpg: 256x416 10 cars, 14.0ms
# image 48/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01d3a4d7-0ccd66c3.jpg: 256x416 8 cars, 14.0ms
# image 49/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01e9deb7-ed388859.jpg: 256x416 3 cars, 14.0ms
# image 50/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\01ec6367-7092c37b.jpg: 256x416 8 cars, 14.0ms
# image 51/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02065c11-0966f65d.jpg: 256x416 2 cars, 14.0ms
# image 52/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02065c11-dbd5d35b.jpg: 256x416 12 cars, 14.0ms
# image 53/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02086f50-c1e5d802.jpg: 256x416 5 cars, 14.0ms
# image 54/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02097021-05dcbf23.jpg: 256x416 11 cars, 14.0ms
# image 55/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02097021-295d2161.jpg: 256x416 4 cars, 14.0ms
# image 56/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\021c4a16-f4d18785.jpg: 256x416 10 cars, 14.0ms
# image 57/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\021cb34f-455d80a0.jpg: 256x416 2 cars, 14.0ms
# image 58/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02346f91-9190074e.jpg: 256x416 5 cars, 15.0ms
# image 59/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02346f91-a62c5e01.jpg: 256x416 3 cars, 14.0ms
# image 60/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\023d0f3c-564e6d31.jpg: 256x416 13 cars, 14.0ms
# image 61/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\024b275b-bbfdf5ee.jpg: 256x416 6 cars, 14.0ms
# image 62/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\024dd592-94359ff1.jpg: 256x416 3 cars, 13.0ms
# image 63/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0252f2b5-2e69185a.jpg: 256x416 11 cars, 14.0ms
# image 64/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\025b2ded-de608724.jpg: 256x416 5 cars, 14.0ms
# image 65/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\025ecc28-3d894af1.jpg: 256x416 2 cars, 14.0ms
# image 66/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02621ea2-399eaeb2.jpg: 256x416 6 cars, 14.0ms
# image 67/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\026501c2-16c41a5d.jpg: 256x416 6 cars, 14.0ms
# image 68/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\026501c2-48a89178.jpg: 256x416 5 cars, 14.0ms
# image 69/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\026d68d3-bb2704f1.jpg: 256x416 1 car, 13.0ms
# image 70/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0276479f-a8bfbd53.jpg: 256x416 4 cars, 14.0ms
# image 71/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\028584e7-6a14163e.jpg: 256x416 4 cars, 14.0ms
# image 72/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0289eba3-3b2c545e.jpg: 256x416 5 cars, 14.0ms
# image 73/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0292ca07-128d078f.jpg: 256x416 11 cars, 13.0ms
# image 74/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0298709e-771de5a8.jpg: 256x416 3 cars, 13.0ms
# image 75/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02a46296-f95ec53f.jpg: 256x416 3 cars, 14.0ms
# image 76/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02ac138c-6bc72d56.jpg: 256x416 8 cars, 14.0ms
# image 77/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02b7b9ee-74fb981c.jpg: 256x416 12 cars, 14.0ms
# image 78/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02b7b9ee-a2aba88b.jpg: 256x416 8 cars, 13.0ms
# image 79/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02c2c31c-d030d8b6.jpg: 256x416 2 cars, 13.0ms
# image 80/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02d478d1-0328a5bf.jpg: 256x416 1 car, 13.0ms
# image 81/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02d478d1-5ffc4cb0.jpg: 256x416 7 cars, 14.0ms
# image 82/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02d478d1-84df3ff0.jpg: 256x416 3 cars, 13.0ms
# image 83/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02d478d1-937f841f.jpg: 256x416 (no detections), 13.0ms
# image 84/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02d478d1-9774e131.jpg: 256x416 8 cars, 13.0ms
# image 85/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02d478d1-9ce5120d.jpg: 256x416 2 cars, 14.0ms
# image 86/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02d478d1-e5ed0eb1.jpg: 256x416 4 cars, 13.0ms
# image 87/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02d91e68-dffa6840.jpg: 256x416 1 car, 13.0ms
# image 88/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02f101f6-56ba9106.jpg: 256x416 4 cars, 14.0ms
# image 89/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02f95a54-6494531c.jpg: 256x416 7 cars, 13.0ms
# image 90/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\02fc82b3-279906a9.jpg: 256x416 12 cars, 13.0ms
# image 91/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\030a6a6c-fca2979d.jpg: 256x416 9 cars, 14.0ms
# image 92/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03112119-0aafd3ad.jpg: 256x416 11 cars, 13.0ms
# image 93/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03112119-a36f2a78.jpg: 256x416 6 cars, 13.0ms
# image 94/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03112119-f95037cc.jpg: 256x416 14 cars, 13.0ms
# image 95/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0315cc1f-d0c40c17.jpg: 256x416 5 cars, 14.0ms
# image 96/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0328e9e5-03177fd8.jpg: 256x416 8 cars, 13.0ms
# image 97/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03370efc-c690f4d8.jpg: 256x416 6 cars, 13.0ms
# image 98/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0339a42b-1e75ac9a.jpg: 256x416 6 cars, 20.0ms
# image 99/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\035268c2-5cf95581.jpg: 256x416 3 cars, 13.0ms
# image 100/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\035821a3-1d1d5abb.jpg: 256x416 5 cars, 13.0ms
# image 101/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\035821a3-9f2a08bc.jpg: 256x416 3 cars, 13.0ms
# image 102/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\037795d6-d456ac0c.jpg: 256x416 1 car, 13.0ms
# image 103/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03a08882-3c5b8923.jpg: 256x416 6 cars, 13.0ms
# image 104/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03a5976c-6d4c6239.jpg: 256x416 6 cars, 13.0ms
# image 105/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03ab1996-72301852.jpg: 256x416 7 cars, 14.0ms
# image 106/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03e19d79-c79b6a0f.jpg: 256x416 9 cars, 13.0ms
# image 107/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03fd9aa1-4be42e2e.jpg: 256x416 2 cars, 13.0ms
# image 108/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\03fd9aa1-78e4c146.jpg: 256x416 7 cars, 13.0ms
# image 109/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0406b065-a759da9c.jpg: 256x416 5 cars, 13.0ms
# image 110/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04076a65-8c1a44ba.jpg: 256x416 5 cars, 13.0ms
# image 111/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04095551-efe2622a.jpg: 256x416 9 cars, 13.0ms
# image 112/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\040fff88-4e31bfdd.jpg: 256x416 2 cars, 13.0ms
# image 113/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\041dc63f-7fe29e93.jpg: 256x416 (no detections), 13.0ms
# image 114/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\043026cb-2808c6fb.jpg: 256x416 4 cars, 13.0ms
# image 115/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\043026cb-a30ed3f0.jpg: 256x416 7 cars, 13.0ms
# image 116/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\043026cb-f72901db.jpg: 256x416 2 cars, 14.0ms
# image 117/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04327108-6fb3ab49.jpg: 256x416 3 cars, 13.0ms
# image 118/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0432d284-c924667e.jpg: 256x416 6 cars, 14.0ms
# image 119/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04488604-72f099d0.jpg: 256x416 7 cars, 13.0ms
# image 120/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\045d32b5-31a5a2dd.jpg: 256x416 5 cars, 13.0ms
# image 121/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04629c39-1d564d8a.jpg: 256x416 8 cars, 19.0ms
# image 122/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04629c39-4a119705.jpg: 256x416 10 cars, 13.0ms
# image 123/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\047a7ecb-68221e4a.jpg: 256x416 3 cars, 13.0ms
# image 124/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\048be7ce-6de74c1d.jpg: 256x416 4 cars, 13.0ms
# image 125/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04a031e9-bd5a1b35.jpg: 256x416 13 cars, 13.0ms
# image 126/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04a4137e-4b7d314e.jpg: 256x416 10 cars, 13.0ms
# image 127/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04c1910d-a814be1b.jpg: 256x416 6 cars, 13.0ms
# image 128/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04dd75bb-9507acc4.jpg: 256x416 9 cars, 13.0ms
# image 129/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04e4e23f-b4b54d4c.jpg: 256x416 5 cars, 14.0ms
# image 130/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04e55a30-fc0b249b.jpg: 256x416 9 cars, 13.0ms
# image 131/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\04f43439-19f3dd47.jpg: 256x416 2 cars, 13.0ms
# image 132/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0505c36e-579b416c.jpg: 256x416 11 cars, 13.0ms
# image 133/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\050fa2e9-9b7dbfdc.jpg: 256x416 2 cars, 13.0ms
# image 134/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05266828-33538181.jpg: 256x416 3 cars, 13.0ms
# image 135/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05266828-79a6ed22.jpg: 256x416 7 cars, 13.0ms
# image 136/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\052fd7cc-b5dee1de.jpg: 256x416 4 cars, 13.0ms
# image 137/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\053dc1d6-29b58579.jpg: 256x416 6 cars, 13.0ms
# image 138/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05476b39-9d783f66.jpg: 256x416 3 cars, 13.0ms
# image 139/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\054a8fc0-6f54c1d9.jpg: 256x416 2 cars, 13.0ms
# image 140/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0573ac53-a5fbd3f3.jpg: 256x416 2 cars, 25.0ms
# image 141/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05771267-dd3b3df8.jpg: 256x416 6 cars, 13.0ms
# image 142/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\057e248a-d682ca97.jpg: 256x416 9 cars, 19.0ms
# image 143/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\057eea5e-7fe988ad.jpg: 256x416 2 cars, 13.0ms
# image 144/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\057f2887-a81b8339.jpg: 256x416 7 cars, 13.0ms
# image 145/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\059249ba-f90bb77e.jpg: 256x416 5 cars, 13.0ms
# image 146/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05968504-c4fab93f.jpg: 256x416 3 cars, 13.0ms
# image 147/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05a93853-0d9f37e7.jpg: 256x416 5 cars, 13.0ms
# image 148/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05ae1d1b-21efb67c.jpg: 256x416 10 cars, 13.0ms
# image 149/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05b06a04-5d7141e0.jpg: 256x416 10 cars, 13.0ms
# image 150/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05ba4355-bf968804.jpg: 256x416 12 cars, 13.0ms
# image 151/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05c1c47a-cb817b64.jpg: 256x416 5 cars, 12.0ms
# image 152/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05c5f168-4102d5dc.jpg: 256x416 4 cars, 12.0ms
# image 153/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05d45cf1-f9c00c3e.jpg: 256x416 4 cars, 13.0ms
# image 154/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05d481cb-cdf61aa2.jpg: 256x416 6 cars, 13.0ms
# image 155/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05e5b952-70bc5050.jpg: 256x416 6 cars, 13.0ms
# image 156/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05ee8e98-485483e2.jpg: 256x416 10 cars, 13.0ms
# image 157/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05f82a66-84fbd096.jpg: 256x416 1 car, 13.0ms
# image 158/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\05fa6494-2fad5381.jpg: 256x416 13 cars, 13.0ms
# image 159/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06086d96-9282b1aa.jpg: 256x416 1 car, 13.0ms
# image 160/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\060f62bd-686c028e.jpg: 256x416 2 cars, 13.0ms
# image 161/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\061b081d-b5e37863.jpg: 256x416 6 cars, 13.0ms
# image 162/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\061e50b9-4632404d.jpg: 256x416 1 car, 13.0ms
# image 163/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06498637-450f7fd2.jpg: 256x416 2 cars, 13.0ms
# image 164/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\065334d1-add77611.jpg: 256x416 5 cars, 12.0ms
# image 165/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0656c6ac-751578f2.jpg: 256x416 6 cars, 13.0ms
# image 166/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0665228f-1274f410.jpg: 256x416 9 cars, 13.0ms
# image 167/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06668f7b-81a4f8e5.jpg: 256x416 6 cars, 13.0ms
# image 168/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\066e4bec-ba100c24.jpg: 256x416 2 cars, 13.0ms
# image 169/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\067449e7-717df154.jpg: 256x416 2 cars, 13.0ms
# image 170/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0675e448-b483aaa4.jpg: 256x416 10 cars, 13.0ms
# image 171/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0676d627-4b8f681b.jpg: 256x416 (no detections), 13.0ms
# image 172/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06791257-8a14ba41.jpg: 256x416 6 cars, 13.0ms
# image 173/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06791257-b5e871c9.jpg: 256x416 7 cars, 13.0ms
# image 174/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06791257-dc3df11b.jpg: 256x416 6 cars, 13.0ms
# image 175/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06791257-e4a5e0a5.jpg: 256x416 7 cars, 12.0ms
# image 176/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\067ebca1-77c243c7.jpg: 256x416 4 cars, 13.0ms
# image 177/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\067f3361-39097fb1.jpg: 256x416 7 cars, 13.0ms
# image 178/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ac374f-364c820e.jpg: 256x416 1 car, 13.0ms
# image 179/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ac374f-5c7f25cf.jpg: 256x416 1 car, 13.0ms
# image 180/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ac7da9-1d958101.jpg: 256x416 9 cars, 13.0ms
# image 181/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ac7da9-81ae9c1c.jpg: 256x416 8 cars, 12.0ms
# image 182/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ac7da9-b4b26aa1.jpg: 256x416 8 cars, 13.0ms
# image 183/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06b6c91e-f989a46e.jpg: 256x416 2 cars, 13.0ms
# image 184/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06cb522f-98fb6b62.jpg: 256x416 7 cars, 13.0ms
# image 185/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06cbfcda-32875f1e.jpg: 256x416 13 cars, 13.0ms
# image 186/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06d1c4fe-4f416689.jpg: 256x416 1 car, 13.0ms
# image 187/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06d501fd-94c914c9.jpg: 256x416 6 cars, 13.0ms
# image 188/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06d54ae6-76749641.jpg: 256x416 3 cars, 13.0ms
# image 189/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06e4a00e-346390c8.jpg: 256x416 4 cars, 13.0ms
# image 190/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06e92935-a5f5bff2.jpg: 256x416 3 cars, 13.0ms
# image 191/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ebf6cd-0c129f12.jpg: 256x416 5 cars, 13.0ms
# image 192/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ebf6cd-79235c8d.jpg: 256x416 5 cars, 14.0ms
# image 193/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ec79fd-3351771d.jpg: 256x416 8 cars, 13.0ms
# image 194/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ec79fd-a832f627.jpg: 256x416 7 cars, 13.0ms
# image 195/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06f7a41e-7dcae57f.jpg: 256x416 6 cars, 12.0ms
# image 196/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06fb4e9c-42c4177c.jpg: 256x416 5 cars, 13.0ms
# image 197/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ff7d61-734f0911.jpg: 256x416 3 cars, 13.0ms
# image 198/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\06ff7d61-8cefb300.jpg: 256x416 8 cars, 13.0ms
# image 199/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\070383db-c693da33.jpg: 256x416 4 cars, 13.0ms
# image 200/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0706e16c-8eb9233a.jpg: 256x416 3 cars, 13.0ms
# image 201/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0710389f-7b28ff14.jpg: 256x416 9 cars, 13.0ms
# image 202/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0710389f-9edbc057.jpg: 256x416 7 cars, 13.0ms
# image 203/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07116ae0-0f12a817.jpg: 256x416 7 cars, 13.0ms
# image 204/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0714456d-2648a0c9.jpg: 256x416 11 cars, 12.0ms
# image 205/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0714456d-4cd21397.jpg: 256x416 7 cars, 13.0ms
# image 206/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0714456d-619b3a70.jpg: 256x416 7 cars, 13.0ms
# image 207/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0714456d-eb7f5c38.jpg: 256x416 5 cars, 13.0ms
# image 208/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0723c4dd-6d50a276.jpg: 256x416 6 cars, 13.0ms
# image 209/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0723c4dd-7a1168dc.jpg: 256x416 3 cars, 13.0ms
# image 210/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0725b3e1-9c9078cb.jpg: 256x416 11 cars, 13.0ms
# image 211/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0738f42e-734821e2.jpg: 256x416 6 cars, 13.0ms
# image 212/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\073b77c8-d1906f40.jpg: 256x416 8 cars, 13.0ms
# image 213/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\074496ba-61bf504e.jpg: 256x416 3 cars, 13.0ms
# image 214/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\074496ba-63007218.jpg: 256x416 9 cars, 12.0ms
# image 215/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07454314-6c00ff73.jpg: 256x416 8 cars, 12.0ms
# image 216/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\076399f2-3cc0e470.jpg: 256x416 6 cars, 13.0ms
# image 217/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\076399f2-4857e5a4.jpg: 256x416 2 cars, 13.0ms
# image 218/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\076399f2-4c68835b.jpg: 256x416 3 cars, 13.0ms
# image 219/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\076399f2-b3108b86.jpg: 256x416 2 cars, 13.0ms
# image 220/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\076399f2-d397b12e.jpg: 256x416 7 cars, 13.0ms
# image 221/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0777595b-cfdfbd26.jpg: 256x416 10 cars, 13.0ms
# image 222/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0778f573-ec85d34b.jpg: 256x416 (no detections), 13.0ms
# image 223/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\077ca90c-2eb997b5.jpg: 256x416 6 cars, 13.0ms
# image 224/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\077ca90c-3a8fcb05.jpg: 256x416 1 car, 13.0ms
# image 225/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\077d7bbc-2dc66d22.jpg: 256x416 3 cars, 13.0ms
# image 226/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\078fe907-795898f3.jpg: 256x416 11 cars, 13.0ms
# image 227/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\078fe907-c39a62fa.jpg: 256x416 10 cars, 13.0ms
# image 228/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07919504-00f3c313.jpg: 256x416 16 cars, 12.0ms
# image 229/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07919504-3a57c8d3.jpg: 256x416 9 cars, 12.0ms
# image 230/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07919504-a04fb42d.jpg: 256x416 3 cars, 13.0ms
# image 231/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0793f9bb-6d2220bb.jpg: 256x416 9 cars, 12.0ms
# image 232/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\079f5ab4-43e6c570.jpg: 256x416 2 cars, 13.0ms
# image 233/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07a3c8b9-28eeac9f.jpg: 256x416 9 cars, 13.0ms
# image 234/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07bfc402-10ede36e.jpg: 256x416 1 car, 13.0ms
# image 235/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07cacc74-5ce6b76a.jpg: 256x416 5 cars, 13.0ms
# image 236/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07cacc74-61869ca0.jpg: 256x416 4 cars, 13.0ms
# image 237/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07cacc74-cd5434f6.jpg: 256x416 2 cars, 13.0ms
# image 238/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\07eb68f5-252839d8.jpg: 256x416 5 cars, 12.0ms
# image 239/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\080ab9ec-8b8c4867.jpg: 256x416 12 cars, 13.0ms
# image 240/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\080ade80-1a838948.jpg: 256x416 9 cars, 13.0ms
# image 241/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0817823b-8a8657e7.jpg: 256x416 1 car, 13.0ms
# image 242/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\081a9205-75de0052.jpg: 256x416 4 cars, 13.0ms
# image 243/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\083174cc-d0d36221.jpg: 256x416 (no detections), 12.0ms
# image 244/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0832b2c1-01c32f0f.jpg: 256x416 5 cars, 13.0ms
# image 245/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0839f8ce-4c797e78.jpg: 256x416 7 cars, 12.0ms
# image 246/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\083bc808-43718f9d.jpg: 256x416 5 cars, 13.0ms
# image 247/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08407547-88a86bf4.jpg: 256x416 (no detections), 12.0ms
# image 248/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0848a7ae-55ee4521.jpg: 256x416 4 cars, 13.0ms
# image 249/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08559e14-86c1c50d.jpg: 256x416 4 cars, 12.0ms
# image 250/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08588924-f78d1a6b.jpg: 256x416 1 car, 13.0ms
# image 251/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0859694a-cc860d1e.jpg: 256x416 3 cars, 13.0ms
# image 252/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08605381-3c49572a.jpg: 256x416 7 cars, 12.0ms
# image 253/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0863712f-8829c77d.jpg: 256x416 11 cars, 12.0ms
# image 254/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08688b9f-1a6e302c.jpg: 256x416 (no detections), 13.0ms
# image 255/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08688b9f-4e2c11c8.jpg: 256x416 4 cars, 13.0ms
# image 256/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0873a422-c932b424.jpg: 256x416 4 cars, 13.0ms
# image 257/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0879ba7f-43a47bb3.jpg: 256x416 11 cars, 13.0ms
# image 258/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\087a33b7-ec85f56a.jpg: 256x416 1 car, 13.0ms
# image 259/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08800a8a-ac06cf56.jpg: 256x416 4 cars, 17.0ms
# image 260/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\088d61b7-a4ec6aaf.jpg: 256x416 2 cars, 13.0ms
# image 261/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0890eeb6-7b4e598f.jpg: 256x416 6 cars, 13.0ms
# image 262/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08952c41-6107aa98.jpg: 256x416 6 cars, 13.0ms
# image 263/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08952c41-61d98712.jpg: 256x416 2 cars, 13.0ms
# image 264/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08952c41-cb9f493d.jpg: 256x416 7 cars, 13.0ms
# image 265/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08952c41-cd2886c9.jpg: 256x416 8 cars, 13.0ms
# image 266/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08a18849-e3f76f44.jpg: 256x416 2 cars, 13.0ms
# image 267/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08a1ba07-dc46f5a3.jpg: 256x416 9 cars, 13.0ms
# image 268/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08aba9b5-9f0927ea.jpg: 256x416 (no detections), 13.0ms
# image 269/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08ad7534-3db5e60b.jpg: 256x416 2 cars, 12.0ms
# image 270/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08ad7534-5dd9b225.jpg: 256x416 7 cars, 13.0ms
# image 271/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08b7e1dc-c621cc6f.jpg: 256x416 5 cars, 13.0ms
# image 272/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08bc375d-20a94856.jpg: 256x416 5 cars, 13.0ms
# image 273/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08c88de6-6cd7fb48.jpg: 256x416 4 cars, 12.0ms
# image 274/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08d0f0fe-55165a5e.jpg: 256x416 5 cars, 12.0ms
# image 275/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08d439aa-2b9c88d7.jpg: 256x416 2 cars, 12.0ms
# image 276/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08e3c891-4faee3d0.jpg: 256x416 8 cars, 12.0ms
# image 277/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08e3c891-51d3dce6.jpg: 256x416 4 cars, 13.0ms
# image 278/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08e4f0af-3b719b39.jpg: 256x416 4 cars, 13.0ms
# image 279/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08ec5fe9-16c339b7.jpg: 256x416 7 cars, 13.0ms
# image 280/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08f22787-8b51e932.jpg: 256x416 7 cars, 12.0ms
# image 281/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\08fd4409-a0d4378a.jpg: 256x416 4 cars, 12.0ms
# image 282/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0919d0a6-27280b18.jpg: 256x416 12 cars, 13.0ms
# image 283/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0919d0a6-b6ec5595.jpg: 256x416 9 cars, 12.0ms
# image 284/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\092183aa-92a87aff.jpg: 256x416 4 cars, 13.0ms
# image 285/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09444e33-9601db9a.jpg: 256x416 8 cars, 13.0ms
# image 286/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\094a88ce-4d08ee61.jpg: 256x416 10 cars, 13.0ms
# image 287/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\097450c5-3e2b46e6.jpg: 256x416 10 cars, 12.0ms
# image 288/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\097450c5-87ec5fcf.jpg: 256x416 6 cars, 13.0ms
# image 289/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0990b5da-2aefc9ce.jpg: 256x416 12 cars, 12.0ms
# image 290/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09952d94-b67d51e0.jpg: 256x416 (no detections), 12.0ms
# image 291/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09993b50-7578df99.jpg: 256x416 9 cars, 13.0ms
# image 292/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\099ea5ca-477562fd.jpg: 256x416 7 cars, 13.0ms
# image 293/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09ac7416-54132cc6.jpg: 256x416 7 cars, 13.0ms
# image 294/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09ac7416-555a8310.jpg: 256x416 6 cars, 12.0ms
# image 295/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09ac7416-6b722ba9.jpg: 256x416 2 cars, 13.0ms
# image 296/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09ac7416-74752083.jpg: 256x416 4 cars, 13.0ms
# image 297/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09ac7416-7c587077.jpg: 256x416 12 cars, 12.0ms
# image 298/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09ac7416-89d3deee.jpg: 256x416 7 cars, 13.0ms
# image 299/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09b80f74-c763ee9b.jpg: 256x416 13 cars, 12.0ms
# image 300/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09be05bd-30224d54.jpg: 256x416 4 cars, 13.0ms
# image 301/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09bee6ab-e0f4268c.jpg: 256x416 5 cars, 12.0ms
# image 302/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09c3b301-3cd9ea61.jpg: 256x416 11 cars, 12.0ms
# image 303/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09cf2788-3645c2cc.jpg: 256x416 6 cars, 12.0ms
# image 304/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09d0e634-7b5c9cdb.jpg: 256x416 2 cars, 12.0ms
# image 305/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09db86ee-c9f4875b.jpg: 256x416 1 car, 19.0ms
# image 306/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09e4ac3a-8126e9c0.jpg: 256x416 5 cars, 13.0ms
# image 307/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09f7f7d3-c41672e4.jpg: 256x416 (no detections), 13.0ms
# image 308/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\09fca634-4e9ac752.jpg: 256x416 11 cars, 13.0ms
# image 309/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a094d1d-0e7bf5d0.jpg: 256x416 11 cars, 12.0ms
# image 310/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a1696f0-4baaff0c.jpg: 256x416 2 cars, 13.0ms
# image 311/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a227e54-ca03e077.jpg: 256x416 2 cars, 13.0ms
# image 312/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a2804db-65f4ffa1.jpg: 256x416 7 cars, 13.0ms
# image 313/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a2804db-72d1407f.jpg: 256x416 7 cars, 12.0ms
# image 314/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a34cf13-82e0dce3.jpg: 256x416 7 cars, 12.0ms
# image 315/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a350edb-6f5c7ef8.jpg: 256x416 4 cars, 13.0ms
# image 316/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a3f8f94-0f3aab2e.jpg: 256x416 2 cars, 12.0ms
# image 317/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a3f8f94-2208fb12.jpg: 256x416 5 cars, 12.0ms
# image 318/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a48c5ed-38e5a6e1.jpg: 256x416 3 cars, 13.0ms
# image 319/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a70b8c5-05f892e4.jpg: 256x416 4 cars, 12.0ms
# image 320/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a70b8c5-2006d229.jpg: 256x416 6 cars, 13.0ms
# image 321/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a7b0436-1a46bb12.jpg: 256x416 6 cars, 12.0ms
# image 322/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a7cbfc6-469c9037.jpg: 256x416 4 cars, 13.0ms
# image 323/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a7cbfc6-bfeebf8d.jpg: 256x416 4 cars, 12.0ms
# image 324/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a7cbfc6-c83c2cde.jpg: 256x416 5 cars, 12.0ms
# image 325/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a7cbfc6-e40c2fde.jpg: 256x416 9 cars, 12.0ms
# image 326/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a8368e0-abaca068.jpg: 256x416 8 cars, 13.0ms
# image 327/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a8aa157-cbfd9075.jpg: 256x416 2 cars, 12.0ms
# image 328/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a9b5ae6-64c75d7a.jpg: 256x416 5 cars, 12.0ms
# image 329/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0a9d03d6-02ea8201.jpg: 256x416 2 cars, 13.0ms
# image 330/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0aa4bc86-1e2d24a2.jpg: 256x416 7 cars, 12.0ms
# image 331/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0aa4bc86-1e9bb591.jpg: 256x416 7 cars, 12.0ms
# image 332/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0ac3cbf4-2bbc1544.jpg: 256x416 5 cars, 13.0ms
# image 333/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0ac3cbf4-a764f88c.jpg: 256x416 4 cars, 13.0ms
# image 334/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0ac3cbf4-ce89456d.jpg: 256x416 4 cars, 12.0ms
# image 335/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0ac6f942-2641cf47.jpg: 256x416 9 cars, 12.0ms
# image 336/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0acc0c71-c476dd2a.jpg: 256x416 8 cars, 13.0ms
# image 337/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0ad99aa9-20ddd733.jpg: 256x416 5 cars, 13.0ms
# image 338/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0af3c46b-df6e403c.jpg: 256x416 9 cars, 12.0ms
# image 339/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0b0c5455-b2513b86.jpg: 256x416 8 cars, 13.0ms
# image 340/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0b37664c-65995ce8.jpg: 256x416 2 cars, 13.0ms
# image 341/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\0b3912a8-ac966f70.jpg: 256x416 8 cars, 13.0ms
# ...
# image 6176/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af19251c-a466e9e8.jpg: 256x416 5 cars, 13.0ms
# image 6177/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af19251c-b77f4819.jpg: 256x416 6 cars, 14.0ms
# image 6178/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af19251c-c4eed45f.jpg: 256x416 5 cars, 13.0ms
# image 6179/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af19251c-d6987987.jpg: 256x416 5 cars, 14.0ms
# image 6180/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af247f4e-fe8cdc34.jpg: 256x416 6 cars, 14.0ms
# image 6181/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af2fe9d3-7fbd0263.jpg: 256x416 5 cars, 14.0ms
# image 6182/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af301273-c8e6c08f.jpg: 256x416 6 cars, 13.0ms
# image 6183/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af36674a-54d0205a.jpg: 256x416 2 cars, 13.0ms
# image 6184/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af36674a-d926ea6a.jpg: 256x416 5 cars, 13.0ms
# image 6185/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af5e53ae-49d487fa.jpg: 256x416 7 cars, 22.0ms
# image 6186/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af5e53ae-4d471df3.jpg: 256x416 5 cars, 13.0ms
# image 6187/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af6e1982-0dc5b62e.jpg: 256x416 7 cars, 13.0ms
# image 6188/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af73f89e-fe3d84c1.jpg: 256x416 6 cars, 14.0ms
# image 6189/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af7d8bc5-9560e283.jpg: 256x416 (no detections), 19.0ms
# image 6190/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af7e1bb8-a944b6c6.jpg: 256x416 6 cars, 14.0ms
# image 6191/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af82cb50-0ee7c3c6.jpg: 256x416 4 cars, 16.0ms
# image 6192/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af8863c7-1d00f521.jpg: 256x416 14 cars, 14.0ms
# image 6193/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af8863c7-fc4552e0.jpg: 256x416 7 cars, 14.0ms
# image 6194/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af8b168e-6c058e36.jpg: 256x416 8 cars, 13.0ms
# image 6195/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af91393a-d75332c6.jpg: 256x416 8 cars, 14.0ms
# image 6196/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af91393a-d8a2669f.jpg: 256x416 4 cars, 14.0ms
# image 6197/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\af960fcf-751dc5ae.jpg: 256x416 (no detections), 14.0ms
# image 6198/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afb45051-b636daf9.jpg: 256x416 2 cars, 14.0ms
# image 6199/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afb45051-e204fbcb.jpg: 256x416 4 cars, 13.0ms
# image 6200/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afb45051-f5be78bc.jpg: 256x416 4 cars, 14.0ms
# image 6201/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afb5f49d-0d0c5897.jpg: 256x416 4 cars, 18.0ms
# image 6202/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afb8014b-d631f950.jpg: 256x416 9 cars, 13.0ms
# image 6203/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afc8f101-18a6a9bb.jpg: 256x416 3 cars, 14.0ms
# image 6204/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afdc295b-5efb0393.jpg: 256x416 11 cars, 14.0ms
# image 6205/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afe34f1d-7dbf8d84.jpg: 256x416 5 cars, 14.0ms
# image 6206/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\afe34f1d-e476a5f4.jpg: 256x416 3 cars, 14.0ms
# image 6207/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\affb45a2-ae54be82.jpg: 256x416 5 cars, 14.0ms
# image 6208/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b001a7ce-5cbc6e0b.jpg: 256x416 7 cars, 13.0ms
# image 6209/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b007edea-158f4588.jpg: 256x416 7 cars, 14.0ms
# image 6210/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b00b16aa-0c6cb201.jpg: 256x416 10 cars, 14.0ms
# image 6211/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b00b16aa-11d594a3.jpg: 256x416 7 cars, 14.0ms
# image 6212/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b00b16aa-379fd986.jpg: 256x416 8 cars, 14.0ms
# image 6213/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b012fb95-ea643247.jpg: 256x416 3 cars, 14.0ms
# image 6214/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0142fc1-7dc241d6.jpg: 256x416 1 car, 14.0ms
# image 6215/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b018c903-d47ef509.jpg: 256x416 8 cars, 14.0ms
# image 6216/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b02523c1-71b12b30.jpg: 256x416 4 cars, 14.0ms
# image 6217/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b02523c1-cd436f0e.jpg: 256x416 5 cars, 14.0ms
# image 6218/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0263f3e-5dcd89e4.jpg: 256x416 5 cars, 14.0ms
# image 6219/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b036eef7-79545c64.jpg: 256x416 3 cars, 14.0ms
# image 6220/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b03d087b-5fc1493e.jpg: 256x416 6 cars, 14.0ms
# image 6221/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b063cb65-81ba2d8d.jpg: 256x416 6 cars, 18.0ms
# image 6222/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b06ef369-50ec9de1.jpg: 256x416 11 cars, 18.0ms
# image 6223/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b072f88d-6934bdff.jpg: 256x416 7 cars, 17.0ms
# image 6224/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b078cd97-b60dbae9.jpg: 256x416 5 cars, 14.0ms
# image 6225/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b082ee87-a9af509d.jpg: 256x416 8 cars, 15.0ms
# image 6226/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b083122c-d2d9aa5c.jpg: 256x416 6 cars, 14.0ms
# image 6227/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b08a0dac-350b992d.jpg: 256x416 3 cars, 14.0ms
# image 6228/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b096b437-139fe906.jpg: 256x416 11 cars, 14.0ms
# image 6229/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0a1dce9-1135e8fe.jpg: 256x416 10 cars, 14.0ms
# image 6230/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0a1dce9-172a4cee.jpg: 256x416 7 cars, 14.0ms
# image 6231/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0a1dce9-4aa6e1ba.jpg: 256x416 3 cars, 14.0ms
# image 6232/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0a1dce9-906b6968.jpg: 256x416 7 cars, 18.0ms
# image 6233/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0a2a5d9-136b6766.jpg: 256x416 3 cars, 14.0ms
# image 6234/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0a3b887-a54e9d59.jpg: 256x416 3 cars, 14.0ms
# image 6235/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0bdafae-3f19231d.jpg: 256x416 8 cars, 14.0ms
# image 6236/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0c6d7c2-042dde83.jpg: 256x416 1 car, 14.0ms
# image 6237/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0c6d7c2-2504309b.jpg: 256x416 2 cars, 14.0ms
# image 6238/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0c6d7c2-892d9d60.jpg: 256x416 7 cars, 14.0ms
# image 6239/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0c83e04-035e6531.jpg: 256x416 7 cars, 14.0ms
# image 6240/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0c83e04-ac586036.jpg: 256x416 4 cars, 14.0ms
# image 6241/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0c89856-ec5c072a.jpg: 256x416 3 cars, 14.0ms
# image 6242/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0ce7f8e-bb14fc5a.jpg: 256x416 4 cars, 14.0ms
# image 6243/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0cf11b7-0e4ff23e.jpg: 256x416 6 cars, 14.0ms
# image 6244/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0d2f2fa-361b5a7a.jpg: 256x416 (no detections), 14.0ms
# image 6245/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0e2920c-b5bc4153.jpg: 256x416 5 cars, 14.0ms
# image 6246/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0f71d5d-949eb873.jpg: 256x416 2 cars, 14.0ms
# image 6247/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b0ff51c1-65721b0d.jpg: 256x416 10 cars, 22.0ms
# image 6248/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1037b5b-0497968a.jpg: 256x416 3 cars, 14.0ms
# image 6249/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1037b5b-ec7f78eb.jpg: 256x416 5 cars, 14.0ms
# image 6250/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b11148e5-f294ade7.jpg: 256x416 5 cars, 18.0ms
# image 6251/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b11aefe3-f7f87739.jpg: 256x416 3 cars, 14.0ms
# image 6252/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b11c4e86-1edd21a9.jpg: 256x416 5 cars, 14.0ms
# image 6253/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b11c4e86-32cb6229.jpg: 256x416 6 cars, 14.0ms
# image 6254/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b11d3a0d-a281dca6.jpg: 256x416 3 cars, 23.0ms
# image 6255/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b11f56d4-2efc450f.jpg: 256x416 10 cars, 14.0ms
# image 6256/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b120546e-ae6126f9.jpg: 256x416 4 cars, 14.0ms
# image 6257/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1205d47-0b5e4b1a.jpg: 256x416 1 car, 14.0ms
# image 6258/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b127cbe6-4db652a5.jpg: 256x416 2 cars, 14.0ms
# image 6259/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b127cbe6-ab165ae9.jpg: 256x416 2 cars, 14.0ms
# image 6260/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b12992c7-905a389e.jpg: 256x416 4 cars, 14.0ms
# image 6261/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b12992c7-bbd57ea0.jpg: 256x416 4 cars, 14.0ms
# image 6262/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b12992c7-fa9e7a33.jpg: 256x416 9 cars, 14.0ms
# image 6263/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b12df0f8-f7504c80.jpg: 256x416 4 cars, 14.0ms
# image 6264/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1329d77-e9de4ba0.jpg: 256x416 3 cars, 14.0ms
# image 6265/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b136762d-cf240165.jpg: 256x416 9 cars, 14.0ms
# image 6266/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b142d842-359a3485.jpg: 256x416 2 cars, 14.0ms
# image 6267/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b142d842-ad07cb04.jpg: 256x416 2 cars, 13.0ms
# image 6268/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1441884-f58755c9.jpg: 256x416 (no detections), 14.0ms
# image 6269/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1463bac-ea427189.jpg: 256x416 5 cars, 14.0ms
# image 6270/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b187a91a-4203ee44.jpg: 256x416 10 cars, 14.0ms
# image 6271/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1892767-1782f101.jpg: 256x416 6 cars, 20.0ms
# image 6272/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b19b87e3-f576fec3.jpg: 256x416 6 cars, 14.0ms
# image 6273/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b19ef5ce-bd67cb37.jpg: 256x416 4 cars, 14.0ms
# image 6274/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1a6893b-aa12c477.jpg: 256x416 4 cars, 14.0ms
# image 6275/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1a9720d-74d8addf.jpg: 256x416 2 cars, 13.0ms
# image 6276/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\b1bc61a3-165e5ad2.jpg: 256x416 6 cars, 14.0ms
# image 6277/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fdc635cc-675d5fc6.jpg: 256x416 4 cars, 14.0ms
# image 6278/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fdd6cabd-240ddcad.jpg: 256x416 6 cars, 14.0ms
# image 6279/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fdd7f0c9-02ee5154.jpg: 256x416 2 cars, 14.0ms
# image 6280/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fde725fc-9baa20b1.jpg: 256x416 9 cars, 14.0ms
# image 6281/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fdf00ecc-0f09e2b4.jpg: 256x416 5 cars, 14.0ms
# image 6282/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fdf00ecc-30d49dac.jpg: 256x416 13 cars, 14.0ms
# image 6283/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fdfacc3c-4d6a7dac.jpg: 256x416 6 cars, 14.0ms
# image 6284/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fe08d8ac-62a9c9a2.jpg: 256x416 13 cars, 14.0ms
# image 6285/6285 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\dataset\images\train\fe095fe7-873e1fff.jpg: 256x416 3 cars, 14.0ms
# Speed: 0.5ms pre-process, 13.7ms inference, 2.0ms NMS per image at shape (1, 3, 416, 416)
# Results saved to C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\runs\infer6
# 6113 labels saved to C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\runs\infer6\labels
# Inference complete. Results saved to runs/infer

# %% [markdown]
# ## Step 6: Display Results (For Presentation)
#
# Load and display the saved results (metrics and inference outputs) without retraining.

# %%
from IPython.display import Image, display
import pandas as pd

# Load the results.csv file
results_path = "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs/adverse_weather_exp5/results.csv"
try:
    metrics_df = pd.read_csv(results_path, skipinitialspace=True, delimiter=',')
except FileNotFoundError:
    print(f"File not found: {results_path}")
    raise
except Exception as e:
    print(f"Error loading CSV: {e}")
    raise

# Strip whitespace from column names
metrics_df.columns = metrics_df.columns.str.strip()

# Print debug information
print("DataFrame Info:")
print(metrics_df.info())
print("\nDataFrame Head:")
print(metrics_df.head())
print("\nAvailable Columns:")
print(metrics_df.columns.tolist())

# Get the last row (final metrics)
final_metrics = metrics_df.iloc[-1]

# Extract key metrics
metrics = {
    "precision": final_metrics["metrics/precision"],
    "recall": final_metrics["metrics/recall"],
    "mAP@0.5": final_metrics["metrics/mAP_0.5"],
    "mAP@0.5:0.95": final_metrics["metrics/mAP_0.5:0.95"]
}

print("\nLoaded Evaluation Metrics:")
print(metrics)
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   epoch                 10 non-null     int64
#  1   train/box_loss        10 non-null     float64
#  2   train/obj_loss        10 non-null     float64
#  3   train/cls_loss        10 non-null     int64
#  4   metrics/precision     10 non-null     float64
#  5   metrics/recall        10 non-null     float64
#  6   metrics/mAP_0.5       10 non-null     float64
#  7   metrics/mAP_0.5:0.95  10 non-null     float64
#  8   val/box_loss          10 non-null     float64
#  9   val/obj_loss          10 non-null     float64
#  10  val/cls_loss          10 non-null     int64
#  11  x/lr0                 10 non-null     float64
#  12  x/lr1                 10 non-null     float64
#  13  x/lr2                 10 non-null     float64
# dtypes: float64(11), int64(3)
# memory usage: 1.2 KB
# None
#
# DataFrame Head:
#    epoch  train/box_loss  train/obj_loss  train/cls_loss  metrics/precision  \
# 0      0        0.100870        0.046497               0            0.67504
# 1      1        0.080715        0.046128               0            0.69852
# 2      2        0.077488        0.044829               0            0.68293
# 3      3        0.073917        0.044904               0            0.71208
# 4      4        0.071766        0.044436               0            0.72768
#
#    ...  val/obj_loss  val/cls_loss    x/lr0     x/lr1     x/lr2
# 0  ...      0.042308             0  0.07001  0.003332  0.003332
# 1  ...      0.041756             0  0.03935  0.006006  0.006006
# 2  ...      0.041556             0  0.00803  0.008019  0.008019
# 3  ...      0.040711             0  0.00703  0.007030  0.007030
# 4  ...      0.040296             0  0.00703  0.007030  0.007030
#
# [5 rows x 14 columns]
#
# Available Columns:
# ['epoch', 'train/box_loss', 'train/obj_loss', 'train/cls_loss', 'metrics/precision', 'metrics/recall', 'metrics/mAP_0.5', 'metrics/mAP_0.5:0.95', 'val/box_loss', 'val/obj_loss', 'val/cls_loss', 'x/lr0', 'x/lr1', 'x/lr2']
#
# Loaded Evaluation Metrics:
# {'precision': 0.75158, 'recall': 0.50356, 'mAP@0.5': 0.57997, 'mAP@0.5:0.95': 0.32923}

# %% [markdown]
# ## Step 7: Test on New Image (For Presentation)
#
# Load the saved model and test it on a new image (e.g., one you take). Update the `new_image_path` to the new image file before running this cell.

# %%
import os
import torch
from yolov5 import detect
from IPython.display import Image, display

# Paths
weights_path = "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs/adverse_weather_exp5/weights/best.pt"
new_image_path = "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/rr.jpeg"  # Replace with the actual path to your new image
new_infer_dir = "C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs/new_infer"

# Create directory for new inference results
os.makedirs(new_infer_dir, exist_ok=True)

# Run inference on the new image
detect.run(
    weights=weights_path,
    source=new_image_path,
    imgsz=(416, 416),  # Use tuple for image size
    conf_thres=0.4,
    device=0 if torch.cuda.is_available() else 'cpu',
    project='C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs',
    name='new_infer',
    save_txt=True,
    save_conf=True,
    nosave=False  # Ensure images are saved (optional, defaults to False)
)

print("Inference on new image complete. Results saved to runs/new_infer")

# Display the output image
output_image_path = os.path.join(new_infer_dir, os.path.basename(new_image_path))  # Matches the input image name
if os.path.exists(output_image_path):
    display(Image(filename=output_image_path))
else:
    print(f"Output image not found at {output_image_path}. Check the runs/new_infer directory for saved files.")
# Out:
# YOLOv5  v7.0-416-gfe1d4d99 Python-3.12.4 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\rr.jpeg: 416x192 (no detections), 115.0ms
# Speed: 0.0ms pre-process, 115.0ms inference, 0.0ms NMS per image at shape (1, 3, 416, 416)
# Results saved to C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\runs\new_infer2
# 0 labels saved to C:\Users\ATbru\Downloads\CODE\AI_ML_DL\Autonomus_Vehicles\runs\new_infer2\labels
# Inference on new image complete. Results saved to runs/new_infer
# Output image not found at C:/Users/ATbru/Downloads/CODE/AI_ML_DL/Autonomus_Vehicles/runs/new_infer\rr.jpeg. Check the runs/new_infer directory for saved files.

# %% [markdown]
# ## Conclusion
#
# - Successfully trained YOLOv5s on ~1,000 BDD100K images with adverse weather conditions.
# - Achieved an mAP of approximately 0.2-0.3 (due to dummy labels).
# - Saved model weights, metrics, and inference outputs for presentation.
# - Ready to show results to the professor without retraining.
